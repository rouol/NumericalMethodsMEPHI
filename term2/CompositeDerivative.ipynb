# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from Solvers import CompositeNumericalDerivative

# %%
f = np.vectorize(lambda x: x ** 5)
X = np.linspace(-1, 1, 100)

# %%
df1 = CompositeNumericalDerivative(f, 0.01, 1)
df2 = CompositeNumericalDerivative(f, 0.01, 2)
df3 = CompositeNumericalDerivative(f, 0.01, 3)
df4 = CompositeNumericalDerivative(f, 0.01, 4)

# %%
# plt.plot(X, f(X), color='red', label='f')
# plt.plot(X, df(X), color='blue', label="f'")
# plt.plot(X, df(X) - np.cos(X), color='purple', label="err f'")

plt.plot(X, f(X), color='red', label='f')
plt.plot(X, df1(X), color='green', label="f1")
plt.plot(X, df2(X), color='orange', label="f2")
plt.plot(X, df3(X), color='blue', label="f3")
plt.plot(X, df4(X), color='purple', label="f4")
# plt.plot(X, (f(X) - df4(X))/f(X), color='black', label="err f4")
plt.legend()
plt.grid()
plt.figure(figsize=(500, 500))
plt.show()
